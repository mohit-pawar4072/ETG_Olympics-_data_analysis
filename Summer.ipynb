# %% [markdown]
# # Summer Olympics Data Analysis Assignment

# %% [markdown]
# ### 1. In how many cities Summer Olympics is held so far?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("summer.csv")

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
# set(df['City'])
df['City'].unique()
# Out:
# array(['Athens', 'Paris', 'St Louis', 'London', 'Stockholm', 'Antwerp',
#        'Amsterdam', 'Los Angeles', 'Berlin', 'Helsinki',
#        'Melbourne / Stockholm', 'Rome', 'Tokyo', 'Mexico', 'Munich',
#        'Montreal', 'Moscow', 'Seoul', 'Barcelona', 'Atlanta', 'Sydney',
#        'Beijing'], dtype=object)

# %% [markdown]
# ### 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
# data = []
# c = 0
# for sport in df['Sport'].unique():
#     # sp = df[df['Sport']==sport]
#     # co = len(sp == "Gold")
#     c = 0 
#     for i in df['Medal'].values:
        
#         if (i == "True"):
#             c += 1
#         data.append([sport,len(df[df['Sport']==c])])

df[df["Medal"]=="Gold"]["Sport"].value_counts().head().plot.bar(figsize = (10,6),color="blue")
plt.xticks(rotation=0, horizontalalignment="center",size=15)
plt.yticks(size=15)
plt.title("Sports with Most Gold Medals",size=15)
plt.xlabel("\nName of the Sport",size=15)
plt.ylabel("Number of Medals",size=15)

# # len(df["Medal"]=="Gold")
# Out:
# Text(0, 0.5, 'Number of Medals')

# %% [markdown]
# ### 3. Which sport is having most number of medals so far? (Top 5)

# %%
df["Sport"].value_counts().head().plot.bar(figsize = (10,7),color="blue")
plt.xticks(rotation=0, horizontalalignment="center",size=15)
plt.yticks(size=15)
plt.title("Sports with Most Medals",size=15)
plt.xlabel("\nSport Name",size=15)
plt.ylabel("Number of Medals",size=15)
# Out:
# Text(0, 0.5, 'Number of Medals')

# %% [markdown]
# ### 4. Which player has won most number of medals? (Top 5)

# %%
df["Athlete"].value_counts().head().plot.bar(figsize = (10,6),color="blue")
plt.xticks(rotation=15, horizontalalignment="center",size=13)
plt.yticks(np.arange(0,24,step=2),size=15)
plt.title("Player with Most Medals",size=15)
plt.xlabel("\nPlayer Name",size=15)
plt.ylabel("Number of Medals",size=15)
# Out:
# Text(0, 0.5, 'Number of Medals')

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
df[df["Medal"]=="Gold"]["Athlete"].value_counts().head().plot.bar(figsize = (13,8),color="blue")
plt.xticks(rotation=0, horizontalalignment="center",size=13)
plt.yticks(np.arange(0, 19, step=2),size=15)
plt.title("Player with Most Gold Medals",size=15)
plt.xlabel("\nPlayer Name",size=15)
plt.ylabel("Number of Medals",size=15)
# Out:
# Text(0, 0.5, 'Number of Medals')

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %%
print(*df[(df["Medal"]=="Gold") &(df["Country"]=="IND")]["Year"].head(1).tolist())
# Out:
# 1928

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players? (Top 5)

# %%
df["Event"].value_counts().head().plot.bar(figsize = (10,6),color="blue")
plt.xticks(rotation=0, horizontalalignment="center",size=15)
plt.yticks(size=15)
plt.title("Most Popular Event",size=15)
plt.xlabel("\nEvent Name",size=15)
plt.ylabel("Number of Players",size=15)
# Out:
# Text(0, 0.5, 'Number of Players')

# %% [markdown]
# ### 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
df[(df["Medal"]=="Gold")&(df["Gender"]=="Women")]["Sport"].value_counts().head().plot.bar(figsize = (10,6),color="blue")
plt.xticks(rotation=0, horizontalalignment="center",size=15)
plt.yticks(size=15)
plt.title("Female Gold Medalist",size=15)
plt.xlabel("\nSport Name",size=15)
plt.ylabel("Number of Medals",size=15)
# Out:
# Text(0, 0.5, 'Number of Medals')
